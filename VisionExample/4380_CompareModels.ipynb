# %% [markdown]
# # Model 1 (MobileNet W/O Augmentation)

# %% [markdown]
# Model 1 (without augmentation): ROC Curve for loss & Val Loss
#
# ![image.png](attachment:image.png)
#
# Model 1 (without augmentation): ROC Curve for accuracy & Val Accuracy
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Model 3 (Xception W/O Augmentation)

# %% [markdown]
# Roc Curve for loss & Val Loss
# ![image.png](attachment:image.png)
#
# The training and validation loss both decrease, but the validation loss seems to stagnate or increase slightly after a certain point, which might suggest the beginning of overfitting.
#
# ROC Curve for accuracy & Val Accuracy
# ![image-2.png](attachment:image-2.png)
#
# If the validation accuracy does not improve or becomes erratic, while training accuracy increases, this typically indicates overfitting

# %% [markdown]
# # Model 4 (InceptionV3 W/O Augmentation)

# %% [markdown]
# Roc Curve for loss & Val Loss
# ![image.png](attachment:image.png)
#
# The loss curves here show more of an ideal situation where both training and validation loss decrease and remain close together, which suggests good generalization compared to our other models.
#
# ROC Curve for accuracy & Val Accuracy
# ![image-2.png](attachment:image-2.png)
#
# shows some overfitting, as the validation loss starts to increase while the training loss continues to decrease.

# %% [markdown]
# # Overview of Models

# %% [markdown]
# MobileNetV2 vs. Xception: The Xception model appears to show an onset of overfitting earlier than MobileNetV2 based on loss curves. If the validation accuracy of the Xception model is less stable or decreases over time, it may not be as robust as the MobileNetV2 model.
#
#
# MobileNetV2 vs. InceptionV3: The InceptionV3 model, based on the third image loss curve, seems to generalize better than MobileNetV2 due to the closeness of the training and validation losses. However, based on the accuracy curve (fourth image), there might be signs of overfitting, which would require more context to determine definitively.
#
#
# Xception vs. InceptionV3: InceptionV3 seems to show better generalization in the loss curve compared to Xception. However, without the accuracy plots for Xception, it's challenging to compare their performance accurately.

# %% [markdown]
# # Performance

# %% [markdown]
# Xception Best Performing:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 53s 13s/step - accuracy: 0.4414 - loss: 1.2426 - val_accuracy: 0.3571 - val_loss: 1.4340
#
# InceptionV3 Best Performing:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.6725 - loss: 0.7661 - val_accuracy: 0.5857 - val_loss: 0.9585
#
# MobileNetV2 Best Performing:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.5367 - loss: 1.0745 - val_accuracy: 0.3571 - val_loss: 1.2636

# %% [markdown]
# # Conclusion

# %% [markdown]
# Based off of ROC curves and perfoamnce comparsion, it does appear that InceptionV3 performs the best compare to the other 2 transfer learning model. Providing better accuracy, lower loss, and higher validation accuracy that are suitable, however, this is without any hyperparameter tuning or augmentations involved to our transfer learning models. As we saw in our first comparsion notebook with augmentation, it can be inferred that augmentation usage with our Xception and InceptionV3 transfer learning models can be benefical and lead to a better overall performing model that'll address the overfitting in most of our curves.
