# %% [markdown]
# # Model 1 (without Augmentation)

# %% [markdown]
# Model 1 (without augmentation): ROC Curve for loss & Val Loss
#
# ![image.png](attachment:image.png)
#
#
# Model 1 (without augmentation): ROC Curve for accuracy & Val Accuracy
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# The training and validation loss both decrease, which is good. However, the validation loss is higher than the training loss, which might suggest a little overfitting.
#
# The validation accuracy is quite erratic and generally lower than the training accuracy, confirming the possibility of overfitting. The model might be learning features specific to the training data that don't generalize well to the validation set.

# %% [markdown]
# # Model 2 (with Augmentation)

# %% [markdown]
# Model 2 (with augmentation): ROC Curve for loss & Val Loss
# ![image.png](attachment:image.png)
#
#
# Model 2 (with augmentation): ROC Curve for accuracy & Val Accuracy
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# The training and validation loss decrease and level off, with the validation loss being lower than the training loss at certain points. Indicating of a good fit, especially as the validation loss remains close to the training loss.
#
#
# The training accuracy is less than the validation accuracy, it suggests that the model is conservative on the training data and performs well on unseen data

# %% [markdown]
# # Conclusion

# %% [markdown]
# Model 2 (with augmentation) appears to be the better model due to its improved generalization as evidenced by the loss and accuracy curves. The training process for Model 2 seems to strike a better balance between learning from the training data and maintaining performance on the validation set.
